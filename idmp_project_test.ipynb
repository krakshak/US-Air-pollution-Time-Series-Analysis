# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
co_df = pd.read_csv('/content/gdrive/MyDrive/IDMP Project/data/CO_2022.csv')
o3_df = pd.read_csv('/content/gdrive/MyDrive/IDMP Project/data/O3_2022.csv')

# %%
df = pd.merge(co_df, o3_df, on = ['Date','State','City'], how ='inner')

# %%
df
# Out:
#               Date   CO Mean  CO 1st  Max Value  CO 1st Max Hour  CO AQI  \
# 0       2022/01/01  0.100000                0.1                0     NaN
# 1       2022/01/01  0.100000                0.1                5     1.0
# 2       2022/01/02  0.145833                0.2               13     NaN
# 3       2022/01/02  0.133333                0.2               16     2.0
# 4       2022/01/04  0.211111                0.3               17     NaN
# ...            ...       ...                ...              ...     ...
# 214713  2022/06/28  0.004167                0.1                0     1.0
# 214714  2022/06/29 -0.300000               -0.2                0     NaN
# 214715  2022/06/29 -0.283333               -0.2                0     0.0
# 214716  2022/06/30 -0.316667               -0.2               13     NaN
# 214717  2022/06/30 -0.320833               -0.3                0     0.0
#
#                                     Address_x        State   County_x  \
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/gdrive/MyDrive/Github
# Out:
# /content/gdrive/MyDrive/Github

# %%
# !git config --global user.name "krakshak"
# !git config --global user.email "krakshak7698@gmail.com"
# !git config --global user.password "caroldanvers&7698"

# %%
token = "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"
username = "krakshak"
repo = "idmp_project"

# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
